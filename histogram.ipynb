# %%
import matplotlib.pyplot as plt
data = [35,55,66,78,56,45,85,90,66,
        44,45,41,28,33,66,99,75,45,
        22,25,36,96,66,68,22,77,45]

# %%
plt.hist(data, bins=5, edgecolor='black')
plt.xlabel = "Marks"
plt.ylabel = "Frequency"
